# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[1,4,10]
z=[8,4,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("First line chart")
plt.xlabel("X")
plt.ylabel("y")

plt.legend(["this is y","this is z"])

# %%
countries=pd.read_csv('countries.csv')

# %%
countries
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
countries.head(1) #if head() then takes 5 by default
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333

# %%
countries.tail(2)
# Out:
#        country  year  population
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
countries.tail()#as it is empty takes 5 as default
# Out:
#        country  year  population
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
# country       1704 non-null object
# year          1704 non-null int64
# population    1704 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 40.0+ KB

# %%
countries[countries['country']=='Finland']
# Out:
#      country  year  population
# 516  Finland  1952     4090500
# 517  Finland  1957     4324000
# 518  Finland  1962     4491443
# 519  Finland  1967     4605744
# 520  Finland  1972     4639657
# 521  Finland  1977     4738902
# 522  Finland  1982     4826933
# 523  Finland  1987     4931729
# 524  Finland  1992     5041039
# 525  Finland  1997     5134406
# 526  Finland  2002     5193039
# 527  Finland  2007     5238460

# %%
sweden=countries[countries['country']=="Sweden"]

# %%
sweden['year']
# Out:
# 1464    1952
# 1465    1957
# 1466    1962
# 1467    1967
# 1468    1972
# 1469    1977
# 1470    1982
# 1471    1987
# 1472    1992
# 1473    1997
# 1474    2002
# 1475    2007
# Name: year, dtype: int64

# %%
sweden['population']
# Out:
# 1464    7124673
# 1465    7363802
# 1466    7561588
# 1467    7867931
# 1468    8122293
# 1469    8251648
# 1470    8325260
# 1471    8421403
# 1472    8718867
# 1473    8897619
# 1474    8954175
# 1475    9031088
# Name: population, dtype: int64

# %%
year=sweden['year']
population=sweden['population']
plt.plot(year,population)
plt.xlabel("year")
plt.ylabel("population")
# Out:
# Text(0, 0.5, 'population')

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
# country       1704 non-null object
# year          1704 non-null int64
# population    1704 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 40.0+ KB

# %%
countries.head(2)
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934

# %%
countries['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
countries['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
unique_countries=countries['country'].unique()

# %%
len(unique_countries)
# Out:
# 142

# %%
normal_list=[1,2,3,2,3,4,1,2]

set1=set(normal_list)#in set there will be no duplicate
set1
# Out:
# {1, 2, 3, 4}

# %%
list2=list(set1)
list2
# Out:
# [1, 2, 3, 4]

# %%
#to define empty list
empty_list=[]
empty_list2=list()
#to define empty set we need to call it
empty_set=set()

empty_dict={}
empty_dict2=dict{}
# Out:
#   File "<ipython-input-46-8b4a7c144037>", line 8
#     empty_dict2=dict{}
#                     ^
# SyntaxError: invalid syntax

# %%
unique_year=countries['year'].unique()

# %%
unique_year
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
len(unique_year)
# Out:
# 12

# %%
142*12 in #total
# Out:
#   File "<ipython-input-50-c1652b0ae1eb>", line 1
#     142*12 in #total
#                      ^
# SyntaxError: invalid syntax

# %%
year=sweden['year']
population=sweden['population']
plt.bar(year,population)
plt.xlabel("year")
plt.ylabel("population")
# Out:
# Text(0, 0.5, 'population')

# %%
year52=countries[countries['year']==1952]
year52
# Out:
#                        country  year  population
# 0                  Afghanistan  1952     8425333
# 12                     Albania  1952     1282697
# 24                     Algeria  1952     9279525
# 36                      Angola  1952     4232095
# 48                   Argentina  1952    17876956
# 60                   Australia  1952     8691212
# 72                     Austria  1952     6927772
# 84                     Bahrain  1952      120447
# 96                  Bangladesh  1952    46886859
# 108                    Belgium  1952     8730405
# 120                      Benin  1952     1738315
# 132                    Bolivia  1952     2883315
# 144     Bosnia and Herzegovina  1952     2791000
# 156                   Botswana  1952      442308
# 168                     Brazil  1952    56602560
# 180                   Bulgaria  1952     7274900
# 192               Burkina Faso  1952     4469979
# 204                    Burundi  1952     2445618
# ...

# %%
plt.figure(figsize =(50,25))
plt.bar(year52['country'],year52['population'])
# Out:
# <BarContainer object of 142 artists>
